# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Criando gráfico básico
array = np.arange(0,10,0.1)
plt.plot(array)
plt.show()

# %%
#Criando seno
seno = np.sin(array)
plt.plot(seno)
plt.show()

# %%
##  Alterando tamanho da imagem, nomes dos eixos e acrescentando titulo

figura = plt.figure(figsize=(5,2))
#colocando o titulo
plt.title("Função Seno")
#plots de seno
plt.plot(seno)
plt.plot(seno*-1)
#colocando os eixos
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.show()

# %%
## mudando cores e estilo de linha e adicionando legenda
plt.plot(seno,color='green',marker='o', label='Seno')
plt.plot(seno*-1,'r--', label='1-Seno')
plt.legend()
plt.show()

# %%
## adicionando legendas em posições pre fixadas
plt.plot(seno,color='green',marker='o', label='Seno')
plt.plot(seno*-1,'r--', label='1-Seno')
plt.legend(frameon=False,loc='upper right')
plt.show()

# %% [markdown]
# # Bar plot

# %% [markdown]
# ## A simple barplot with single bars

# %%
country = ['INDIA', 'JAPAN', 'CHINA', 'USA', 'GERMANY']
population = [1000,800,600,400,1100]
plt.bar(country,population)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,3,7,1,0]) #tamanho dos eixos

# %%
plot_title = "Simple bar plot"
x_axis = "Number"
y_axis = "Lenght"

# %%
plt.title(plot_title)
plt.xlabel(x_axis)
plt.ylabel(y_axis)

# Barplot
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Bar plot with multiple bars to comparisons

# %%
x1 = np.array([1,3,5,7,9])
y1 = np.array([2,3,7,1,0]) # tamanho dos eixos 1


x2 = np.array([2,4,6,8,10])
y2 = np.array([5,1,3,7,4]) # tamanho dos eixos 2

# %%
#barplot com legendas
plt.bar(x1,y1, label = "Grup 1") #label = título das legendas
plt.bar(x2,y2, label = "Grup 2")
plt.legend()
plt.title("Bar plot")
plt.xlabel("Number")
plt.ylabel("Bar lenght")
plt.show()

# %% [markdown]
# # Scatterplot

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,3,7,1,0])

# %%
plot_title = "Scatterplot"
x_axis = "Number"
y_axis = "Lenght"

# %% [markdown]
# ## Simple scatterplot

# %%
# scatterplot
plt.scatter(x,y)

plt.title(plot_title)
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()

# %%
plt.title(plot_title)
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.plot(x,y, color = "#990000", linestyle = "--") # Ligando os pontos com uma linha tracejada
plt.show()

# %%
# Criando os pontos com tamanhos distintos

x = np.array([1,2,3,4,5])
y = np.array([2,3,7,1,0])
z = np.array([200,25,400,3300,100]) # tamanho dos circulos

# %%
#color = Point's color (black), marker = Marker type (.), s = marker's lenght (circle's lenght)
plt.scatter(x,y, label = "My points", color = "k", marker = ".", s = z)

plt.plot(x,y, color = "#990000", linestyle = "--") #Linha para ligar os pontos
plt.legend()
plt.show()

# %% [markdown]
# # Boxplot

# %%
# Construindo um array numpy aleatório com: o número 1 é o valor mínimo, o número 5 é o máximo e o vetor contém 10 números
aleatory_vector = np.random.randint(low=1, high=5, size=10)

plt.boxplot(aleatory_vector)
plt.title("Boxplot")
plt.show()

# %% [markdown]
# # Gráfico de Pizza

# %%
cars = ['AUDI', 'BMW', 'FORD', 
        'TESLA', 'JAGUAR', 'MERCEDES'] 
  
data = [23, 17, 35, 29, 12, 41] 
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = cars) 
plt.show()

# %%
cars = ['AUDI', 'BMW', 'FORD', 
        'TESLA', 'JAGUAR', 'MERCEDES'] 
  
data = [23, 17, 35, 29, 12, 41] 
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = cars, textprops=dict(fontsize=12, color = 'w'), autopct='%.1f%%')  
plt.show()

# %%
def func(pct, allvals):
    #print(pct)
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n pop: ({absolute:d} )"

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = cars, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))
plt.show()

# %%
# explosão
explode = (0, 0.1, 0, 0, 0, 0)

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = cars, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"), explode=explode)
plt.show()

# %% [markdown]
# # Gráfico de Rosca

# %%
# explosão
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = cars, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"), explode=explode)


# desenho de um circulo
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf() # gcf = get the current figure
 
# Adicionando o circulo ao gráfico
# gca = get the current axes
fig.gca().add_artist(centre_circle)
plt.show()

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = cars, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"), explode=explode, 
                                  pctdistance=0.85) # distancia em relacao ao raio da circunferencia)


# desenho de um circulo
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf() # pega a figura atual
 
# Adicionando o circulo ao gráfico
fig.gca().add_artist(centre_circle) #gca pega os eixos (atributos do gráfico)
plt.show()

# %% [markdown]
# # Using datasets

# %%
import pandas as pd
df = pd.read_csv("../../Datasets/populacao_brasileira.csv", sep = ";")

# %%
df.head()
# Out:
#    year  population
# 0  1980   119011052
# 1  1981   121154159
# 2  1982   123774229
# 3  1983   126403352
# 4  1984   129025577

# %%
df['year'] = df['year'].astype(int)
df['population'] = df['population'].astype(int)

# %%
plt.bar(df['year'],df['population'], color = "#e4e4e4") # barplot
plt.plot(df['year'],df['population'], color = "k", linestyle = "--") # lineplot

plt.title("Growth of the Brazilian population (1980-2016)")
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()

# %%
#boxplot
plt.boxplot(df['population'])
plt.xlabel("Population")
plt.ylabel("Numbers")
plt.title("Boxplot")
plt.show()

# %%
df_iris = pd.read_csv('../../datasets/Iris.csv') 
#print(df_iris.columns)
plt.scatter(df_iris['SepalLengthCm'], df_iris['SepalWidthCm'])
plt.show()

# %%
df_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df_iris.hist(figsize=(16, 8), grid=False)
plt.show()

# %%
plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,10))

plt.subplot(2, 2, 1)
plt.boxplot(df_iris['SepalLengthCm'])
plt.title('Sepal Length (cm)')

plt.subplot(2, 2, 2)
plt.boxplot(df_iris['SepalWidthCm'])
plt.title('Sepal Width (cm)')

plt.subplot(2, 2, 3)
plt.boxplot(df_iris['PetalLengthCm'])
plt.title('Petal Length (cm)')

plt.subplot(2, 2, 4)
plt.boxplot(df_iris['PetalWidthCm'])
plt.title('Petal Width (cm)')

plt.show()
